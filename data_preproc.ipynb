# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_csv('../data/Phenotypic_V1_0b_preprocessed1.csv')
df2.shape
# Out:
# (1112, 106)

# %%
df2.groupby(["SITE_ID"]).count()
# Out:
#           Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject  FILE_ID  DX_GROUP  \
# SITE_ID
# CALTECH             38          38      38   38       38       38        38
# CMU                 27          27      27   27       27       27        27
# KKI                 55          55      55   55       55       55        55
# LEUVEN_1            29          29      29   29       29       29        29
# LEUVEN_2            35          35      35   35       35       35        35
# MAX_MUN             57          57      57   57       57       57        57
# NYU                184         184     184  184      184      184       184
# OHSU                28          28      28   28       28       28        28
# OLIN                36          36      36   36       36       36        36
# PITT                57          57      57   57       57       57        57
# SBL                 30          30      30   30       30       30        30
# ...

# %%
df_copy = df2.copy()
df_copy[df_copy["SITE_ID"] == "CALTECH"]
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 1042          1042        1043   51456  1043    51456  CALTECH
# 1043          1043        1044   51457  1044    51457  CALTECH
# 1044          1044        1045   51458  1045    51458  CALTECH
# 1045          1045        1046   51459  1046    51459  CALTECH
# 1046          1046        1047   51460  1047    51460  CALTECH
# 1047          1047        1048   51461  1048    51461  CALTECH
# 1048          1048        1049   51462  1049    51462  CALTECH
# 1049          1049        1050   51463  1050    51463  CALTECH
# 1050          1050        1051   51464  1051    51464  CALTECH
# 1051          1051        1052   51465  1052    51465  CALTECH
# 1052          1052        1053   51466  1053    51466  CALTECH
# 1053          1053        1054   51467  1054    51467  CALTECH
# 1054          1054        1055   51468  1055    51468  CALTECH
# 1055          1055        1056   51469  1056    51469  CALTECH
# ...

# %%
columns = ["SITE_ID","SUB_ID"]
print(df_copy[df_copy["FILE_ID"] == "no_filename"][columns].to_string())
# Out:
#        SITE_ID  SUB_ID
# 0         PITT   50002
# 63        OLIN   50108
# 92        OLIN   50137
# 104       OHSU   50155
# 114       OHSU   50165
# 163    TRINITY   50238
# 169    TRINITY   50244
# 232       UM_1   50309
# 246       UM_1   50323
# 251       UM_1   50328
# 301       UM_1   50378
# 334       UM_2   50423
# 340        USM   50432
# 358        USM   50450
# 359        USM   50451
# 360        USM   50452
# 362        USM   50454
# 364        USM   50456
# 365        USM   50457
# 366        USM   50458
# 367        USM   50459
# 368        USM   50460
# 369        USM   50461
# 370        USM   50462
# 372        USM   50464
# 373        USM   50465
# 379        USM   50471
# 380        USM   50472
# 381        USM   50473
# 382        USM   50474
# 383        USM   50475
# 384        USM   50476
# 386        USM   50478
# 387        USM   50479
# 392        USM   50484
# 403        USM   50495
# 414        USM   50506
# 416        USM   50508
# 420        USM   50512
# ...

# %%
df_copy = df_copy[df_copy["FILE_ID"] != "no_filename"]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 1                1           2   50003     2    50003     PITT
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 1         Pitt_0050003         1          1        24.45  ...
# 2         Pitt_0050004         1          1        19.09  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "CALTECH"]
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 1042          1042        1043   51456  1043    51456  CALTECH
# 1043          1043        1044   51457  1044    51457  CALTECH
# 1044          1044        1045   51458  1045    51458  CALTECH
# 1045          1045        1046   51459  1046    51459  CALTECH
# 1046          1046        1047   51460  1047    51460  CALTECH
# 1047          1047        1048   51461  1048    51461  CALTECH
# 1048          1048        1049   51462  1049    51462  CALTECH
# 1049          1049        1050   51463  1050    51463  CALTECH
# 1050          1050        1051   51464  1051    51464  CALTECH
# 1051          1051        1052   51465  1052    51465  CALTECH
# 1052          1052        1053   51466  1053    51466  CALTECH
# 1053          1053        1054   51467  1054    51467  CALTECH
# 1054          1054        1055   51468  1055    51468  CALTECH
# 1055          1055        1056   51469  1056    51469  CALTECH
# ...

# %%
df_copy[df_copy["SITE_ID"] == "CMU"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject SITE_ID        FILE_ID  \
# 497           497         498   50642  498    50642     CMU  CMU_a_0050642
# 498           498         499   50643  499    50643     CMU  CMU_b_0050643
# 499           499         500   50644  500    50644     CMU  CMU_b_0050644
# 500           500         501   50645  501    50645     CMU  CMU_b_0050645
# 501           501         502   50646  502    50646     CMU  CMU_a_0050646
# 502           502         503   50647  503    50647     CMU  CMU_a_0050647
# 503           503         504   50648  504    50648     CMU  CMU_b_0050648
# 504           504         505   50649  505    50649     CMU  CMU_a_0050649
# 505           505         506   50650  506    50650     CMU  CMU_b_0050650
# 506           506         507   50651  507    50651     CMU  CMU_b_0050651
# 507           507         508   50652  508    50652     CMU  CMU_b_0050652
# ...

# %%
CMU_mask = ((df_copy["SITE_ID"] != "CMU") | ((df_copy["FILE_ID"] == "CMU_a_0050649") |
              (df_copy["FILE_ID"] == "CMU_a_0050653") |
              (df_copy["FILE_ID"] == "CMU_b_0050651") | 
              (df_copy["FILE_ID"] == "CMU_b_0050657") |
               (df_copy["FILE_ID"] == "CMU_b_0050669")))
df_copy = df_copy[CMU_mask]

# %%
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 1                1           2   50003     2    50003     PITT
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 1         Pitt_0050003         1          1        24.45  ...
# 2         Pitt_0050004         1          1        19.09  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "KKI"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject SITE_ID      FILE_ID  \
# 588           588         589   50772  589    50772     KKI  KKI_0050772
# 589           589         590   50773  590    50773     KKI  KKI_0050773
# 590           590         591   50774  591    50774     KKI  KKI_0050774
# 591           591         592   50775  592    50775     KKI  KKI_0050775
# 592           592         593   50776  593    50776     KKI  KKI_0050776
# 593           593         594   50777  594    50777     KKI  KKI_0050777
# 594           594         595   50778  595    50778     KKI  KKI_0050778
# 595           595         596   50779  596    50779     KKI  KKI_0050779
# 596           596         597   50780  597    50780     KKI  KKI_0050780
# 597           597         598   50781  598    50781     KKI  KKI_0050781
# 598           598         599   50782  599    50782     KKI  KKI_0050782
# 599           599         600   50783  600    50783     KKI  KKI_0050783
# ...

# %%
KKI_mask = ((df_copy["SITE_ID"] != "KKI") | ((df_copy["FILE_ID"] != "KKI_0050784") &
              (df_copy["FILE_ID"] != "KKI_0050793") &
              (df_copy["FILE_ID"] != "KKI_0050794") & 
              (df_copy["FILE_ID"] != "KKI_0050796") &
               (df_copy["FILE_ID"] != "KKI_0050797") &
               (df_copy["FILE_ID"] != "KKI_0050801") &
               (df_copy["FILE_ID"] != "KKI_0050807") &
               (df_copy["FILE_ID"] != "KKI_0050815") &
               (df_copy["FILE_ID"] != "KKI_0050826")
               ))
df_copy = df_copy[KKI_mask]
# df_copy[df_copy["SITE_ID"] == "KKI"][KKI_mask]

# %%
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 1                1           2   50003     2    50003     PITT
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 1         Pitt_0050003         1          1        24.45  ...
# 2         Pitt_0050004         1          1        19.09  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "LEUVEN_2"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject   SITE_ID  \
# 553           553         554   50722  554    50722  LEUVEN_2
# 554           554         555   50723  555    50723  LEUVEN_2
# 555           555         556   50724  556    50724  LEUVEN_2
# 556           556         557   50725  557    50725  LEUVEN_2
# 557           557         558   50726  558    50726  LEUVEN_2
# 558           558         559   50727  559    50727  LEUVEN_2
# 559           559         560   50728  560    50728  LEUVEN_2
# 560           560         561   50730  561    50730  LEUVEN_2
# 561           561         562   50731  562    50731  LEUVEN_2
# 562           562         563   50732  563    50732  LEUVEN_2
# 563           563         564   50733  564    50733  LEUVEN_2
# 565           565         566   50735  566    50735  LEUVEN_2
# 566           566         567   50736  567    50736  LEUVEN_2
# 567           567         568   50737  568    50737  LEUVEN_2
# ...

# %%
LEUVEN_2_mask = ((df_copy["SITE_ID"] != "LEUVEN_2") | ((df_copy["FILE_ID"] != "Leuven_2_0050744") &
              (df_copy["FILE_ID"] != "Leuven_2_0050750")
               ))
df_copy = df_copy[LEUVEN_2_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 1                1           2   50003     2    50003     PITT
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 1         Pitt_0050003         1          1        24.45  ...
# 2         Pitt_0050004         1          1        19.09  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "MAX_MUN"]
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 987            987         988   51318   988    51318  MAX_MUN
# 988            988         989   51319   989    51319  MAX_MUN
# 989            989         990   51320   990    51320  MAX_MUN
# 990            990         991   51321   991    51321  MAX_MUN
# 991            991         992   51322   992    51322  MAX_MUN
# 992            992         993   51323   993    51323  MAX_MUN
# 993            993         994   51324   994    51324  MAX_MUN
# 994            994         995   51325   995    51325  MAX_MUN
# 995            995         996   51326   996    51326  MAX_MUN
# 996            996         997   51327   997    51327  MAX_MUN
# 997            997         998   51328   998    51328  MAX_MUN
# 998            998         999   51329   999    51329  MAX_MUN
# 999            999        1000   51330  1000    51330  MAX_MUN
# 1000          1000        1001   51331  1001    51331  MAX_MUN
# ...

# %%
MAX_MUN_mask = ((df_copy["SITE_ID"] != "MAX_MUN") | ((df_copy["FILE_ID"] != "MaxMun_a_0051320") &
              (df_copy["FILE_ID"] != "MaxMun_c_0051341") &
              (df_copy["FILE_ID"] != "MaxMun_c_0051348") & 
              (df_copy["FILE_ID"] != "MaxMun_d_0051350") &
               (df_copy["FILE_ID"] != "MaxMun_d_0051352") &
               (df_copy["FILE_ID"] != "MaxMun_d_0051353") &
               (df_copy["FILE_ID"] != "MaxMun_d_0051354") &
               (df_copy["FILE_ID"] != "MaxMun_d_0051358") &
               (df_copy["FILE_ID"] != "MaxMun_d_0051359") &
               (df_copy["FILE_ID"] != "MaxMun_d_0051361")
               ))
# df_copy[df_copy["SITE_ID"] == "MAX_MUN"][MAX_MUN_mask]
df_copy = df_copy[MAX_MUN_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 1                1           2   50003     2    50003     PITT
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 1         Pitt_0050003         1          1        24.45  ...
# 2         Pitt_0050004         1          1        19.09  ...
# ...

# %%
print(df_copy[df_copy["SITE_ID"] == "NYU"]["FILE_ID"].to_string())
# Out:
# 643    NYU_0050952
# 645    NYU_0050954
# 646    NYU_0050955
# 647    NYU_0050956
# 648    NYU_0050957
# 649    NYU_0050958
# 650    NYU_0050959
# 651    NYU_0050960
# 652    NYU_0050961
# 653    NYU_0050962
# 654    NYU_0050964
# 655    NYU_0050965
# 656    NYU_0050966
# 657    NYU_0050967
# 658    NYU_0050968
# 659    NYU_0050969
# 660    NYU_0050970
# 662    NYU_0050972
# 663    NYU_0050973
# 664    NYU_0050974
# 666    NYU_0050976
# 667    NYU_0050977
# 668    NYU_0050978
# 669    NYU_0050979
# 671    NYU_0050981
# 672    NYU_0050982
# 673    NYU_0050983
# 674    NYU_0050984
# 675    NYU_0050985
# 676    NYU_0050986
# 677    NYU_0050987
# 678    NYU_0050988
# 679    NYU_0050989
# 680    NYU_0050990
# 681    NYU_0050991
# 682    NYU_0050992
# 683    NYU_0050993
# 684    NYU_0050994
# 685    NYU_0050995
# 686    NYU_0050996
# 687    NYU_0050997
# 688    NYU_0050998
# 689    NYU_0050999
# 690    NYU_0051000
# 691    NYU_0051001
# 692    NYU_0051002
# 693    NYU_0051003
# ...

# %%
NYU_mask = ((df_copy["SITE_ID"] != "NYU") | ((df_copy["FILE_ID"] != "NYU_0050952") &
              (df_copy["FILE_ID"] != "NYU_0051030") &
              (df_copy["FILE_ID"] != "NYU_0051127") & 
              (df_copy["FILE_ID"] != "NYU_0051159")
               ))
# df_copy[df_copy["SITE_ID"] == "NYU"][NYU_mask]
df_copy = df_copy[NYU_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 1                1           2   50003     2    50003     PITT
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 1         Pitt_0050003         1          1        24.45  ...
# 2         Pitt_0050004         1          1        19.09  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "OHSU"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject SITE_ID       FILE_ID  \
# 93             93          94   50142   94    50142    OHSU  OHSU_0050142
# 94             94          95   50143   95    50143    OHSU  OHSU_0050143
# 95             95          96   50144   96    50144    OHSU  OHSU_0050144
# 96             96          97   50145   97    50145    OHSU  OHSU_0050145
# 97             97          98   50146   98    50146    OHSU  OHSU_0050146
# 98             98          99   50147   99    50147    OHSU  OHSU_0050147
# 99             99         100   50148  100    50148    OHSU  OHSU_0050148
# 100           100         101   50149  101    50149    OHSU  OHSU_0050149
# 101           101         102   50150  102    50150    OHSU  OHSU_0050150
# 102           102         103   50152  103    50152    OHSU  OHSU_0050152
# 103           103         104   50153  104    50153    OHSU  OHSU_0050153
# 105           105         106   50156  106    50156    OHSU  OHSU_0050156
# ...

# %%
OHSU_mask = ((df_copy["SITE_ID"] != "OHSU") | ((df_copy["FILE_ID"] != "OHSU_0050162") &
              (df_copy["FILE_ID"] != "OHSU_0050163") &
              (df_copy["FILE_ID"] != "OHSU_0050164")
               ))
# df_copy[df_copy["SITE_ID"] == "OHSU"][OHSU_mask]
df_copy = df_copy[OHSU_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 1                1           2   50003     2    50003     PITT
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 1         Pitt_0050003         1          1        24.45  ...
# 2         Pitt_0050004         1          1        19.09  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "OLIN"]
# Out:
#     Unnamed: 0.1  Unnamed: 0  SUB_ID   X  subject SITE_ID       FILE_ID  \
# 57            57          58   50102  58    50102    OLIN  Olin_0050102
# 58            58          59   50103  59    50103    OLIN  Olin_0050103
# 59            59          60   50104  60    50104    OLIN  Olin_0050104
# 60            60          61   50105  61    50105    OLIN  Olin_0050105
# 61            61          62   50106  62    50106    OLIN  Olin_0050106
# 62            62          63   50107  63    50107    OLIN  Olin_0050107
# 64            64          65   50109  65    50109    OLIN  Olin_0050109
# 65            65          66   50110  66    50110    OLIN  Olin_0050110
# 66            66          67   50111  67    50111    OLIN  Olin_0050111
# 67            67          68   50112  68    50112    OLIN  Olin_0050112
# 68            68          69   50113  69    50113    OLIN  Olin_0050113
# 69            69          70   50114  70    50114    OLIN  Olin_0050114
# ...

# %%
OLIN_mask = ((df_copy["SITE_ID"] != "OLIN") | ((df_copy["FILE_ID"] != "Olin_0050103") &
              (df_copy["FILE_ID"] != "Olin_0050106") &
              (df_copy["FILE_ID"] != "Olin_0050109") &
              (df_copy["FILE_ID"] != "Olin_0050110") &
              (df_copy["FILE_ID"] != "Olin_0050120") &
              (df_copy["FILE_ID"] != "Olin_0050123") &
              (df_copy["FILE_ID"] != "Olin_0050124") &
              (df_copy["FILE_ID"] != "Olin_0050126") &
              (df_copy["FILE_ID"] != "Olin_0050135")
               ))
# df_copy[df_copy["SITE_ID"] == "OLIN"][OLIN_mask]
df_copy = df_copy[OLIN_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 1                1           2   50003     2    50003     PITT
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 1         Pitt_0050003         1          1        24.45  ...
# 2         Pitt_0050004         1          1        19.09  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "PITT"]
# Out:
#     Unnamed: 0.1  Unnamed: 0  SUB_ID   X  subject SITE_ID       FILE_ID  \
# 1              1           2   50003   2    50003    PITT  Pitt_0050003
# 2              2           3   50004   3    50004    PITT  Pitt_0050004
# 3              3           4   50005   4    50005    PITT  Pitt_0050005
# 4              4           5   50006   5    50006    PITT  Pitt_0050006
# 5              5           6   50007   6    50007    PITT  Pitt_0050007
# 6              6           7   50008   7    50008    PITT  Pitt_0050008
# 7              7           8   50009   8    50009    PITT  Pitt_0050009
# 8              8           9   50010   9    50010    PITT  Pitt_0050010
# 9              9          10   50011  10    50011    PITT  Pitt_0050011
# 10            10          11   50012  11    50012    PITT  Pitt_0050012
# 11            11          12   50013  12    50013    PITT  Pitt_0050013
# 12            12          13   50014  13    50014    PITT  Pitt_0050014
# ...

# %%
PITT_mask = ((df_copy["SITE_ID"] != "PITT") | ((df_copy["FILE_ID"] != "Pitt_0050003") &
              (df_copy["FILE_ID"] != "Pitt_0050013") &
              (df_copy["FILE_ID"] != "Pitt_0050017") &
              (df_copy["FILE_ID"] != "Pitt_0050019") &
              (df_copy["FILE_ID"] != "Pitt_0050026") &
              (df_copy["FILE_ID"] != "Pitt_0050028") &
              (df_copy["FILE_ID"] != "Pitt_0050039") &
              (df_copy["FILE_ID"] != "Pitt_0050043") &
              (df_copy["FILE_ID"] != "Pitt_0050049") &
              (df_copy["FILE_ID"] != "Pitt_0050053") &
              (df_copy["FILE_ID"] != "Pitt_0050054")
               ))
# df_copy[df_copy["SITE_ID"] == "PITT"][PITT_mask]
df_copy = df_copy[PITT_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "SBL"]
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject SITE_ID      FILE_ID  \
# 1080          1080        1081   51556  1081    51556     SBL  SBL_0051556
# 1081          1081        1082   51557  1082    51557     SBL  SBL_0051557
# 1082          1082        1083   51558  1083    51558     SBL  SBL_0051558
# 1083          1083        1084   51559  1084    51559     SBL  SBL_0051559
# 1084          1084        1085   51560  1085    51560     SBL  SBL_0051560
# 1085          1085        1086   51561  1086    51561     SBL  SBL_0051561
# 1086          1086        1087   51562  1087    51562     SBL  SBL_0051562
# 1087          1087        1088   51563  1088    51563     SBL  SBL_0051563
# 1088          1088        1089   51564  1089    51564     SBL  SBL_0051564
# 1089          1089        1090   51565  1090    51565     SBL  SBL_0051565
# 1090          1090        1091   51566  1091    51566     SBL  SBL_0051566
# ...

# %%
SBL_mask = ((df_copy["SITE_ID"] != "SBL") | ((df_copy["FILE_ID"] != "SBL_0051568") &
              (df_copy["FILE_ID"] != "SBL_0051569") &
              (df_copy["FILE_ID"] != "SBL_0051575") &
              (df_copy["FILE_ID"] != "SBL_0051556")
               ))
# df_copy[df_copy["SITE_ID"] == "SBL"][SBL_mask]
df_copy = df_copy[SBL_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "SDSU"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject SITE_ID       FILE_ID  \
# 121           121         122   50182  122    50182    SDSU  SDSU_0050182
# 122           122         123   50183  123    50183    SDSU  SDSU_0050183
# 123           123         124   50184  124    50184    SDSU  SDSU_0050184
# 124           124         125   50185  125    50185    SDSU  SDSU_0050185
# 125           125         126   50186  126    50186    SDSU  SDSU_0050186
# 126           126         127   50187  127    50187    SDSU  SDSU_0050187
# 127           127         128   50188  128    50188    SDSU  SDSU_0050188
# 128           128         129   50189  129    50189    SDSU  SDSU_0050189
# 129           129         130   50190  130    50190    SDSU  SDSU_0050190
# 130           130         131   50191  131    50191    SDSU  SDSU_0050191
# 131           131         132   50192  132    50192    SDSU  SDSU_0050192
# 132           132         133   50193  133    50193    SDSU  SDSU_0050193
# ...

# %%
SDSU_mask = ((df_copy["SITE_ID"] != "SDSU") | ((df_copy["FILE_ID"] != "SDSU_0050185") &
              (df_copy["FILE_ID"] != "SDSU_0050192") &
              (df_copy["FILE_ID"] != "SDSU_0050202")
               ))
# df_copy[df_copy["SITE_ID"] == "SDSU"][SDSU_mask]
df_copy = df_copy[SDSU_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "STANFORD"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject   SITE_ID  \
# 838           838         839   51160  839    51160  STANFORD
# 839           839         840   51161  840    51161  STANFORD
# 840           840         841   51162  841    51162  STANFORD
# 841           841         842   51163  842    51163  STANFORD
# 842           842         843   51164  843    51164  STANFORD
# 843           843         844   51165  844    51165  STANFORD
# 844           844         845   51166  845    51166  STANFORD
# 845           845         846   51167  846    51167  STANFORD
# 846           846         847   51168  847    51168  STANFORD
# 847           847         848   51169  848    51169  STANFORD
# 848           848         849   51170  849    51170  STANFORD
# 849           849         850   51171  850    51171  STANFORD
# 850           850         851   51172  851    51172  STANFORD
# 851           851         852   51173  852    51173  STANFORD
# ...

# %%
STANFORD_mask = ((df_copy["SITE_ID"] != "STANFORD") | ((df_copy["FILE_ID"] != "Stanford_0051161") &
              (df_copy["FILE_ID"] != "Stanford_0051166") &
              (df_copy["FILE_ID"] != "Stanford_0051195")
               ))
# df_copy[df_copy["SITE_ID"] == "STANFORD"][STANFORD_mask]
df_copy = df_copy[STANFORD_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "TRINITY"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject  SITE_ID          FILE_ID  \
# 157           157         158   50232  158    50232  TRINITY  Trinity_0050232
# 158           158         159   50233  159    50233  TRINITY  Trinity_0050233
# 159           159         160   50234  160    50234  TRINITY  Trinity_0050234
# 160           160         161   50235  161    50235  TRINITY  Trinity_0050235
# 161           161         162   50236  162    50236  TRINITY  Trinity_0050236
# 162           162         163   50237  163    50237  TRINITY  Trinity_0050237
# 164           164         165   50239  165    50239  TRINITY  Trinity_0050239
# 165           165         166   50240  166    50240  TRINITY  Trinity_0050240
# 166           166         167   50241  167    50241  TRINITY  Trinity_0050241
# 167           167         168   50242  168    50242  TRINITY  Trinity_0050242
# 168           168         169   50243  169    50243  TRINITY  Trinity_0050243
# ...

# %%
Trinity_mask = ((df_copy["SITE_ID"] != "TRINITY") | ((df_copy["FILE_ID"] != "Trinity_0050242") &
              (df_copy["FILE_ID"] != "Trinity_0050265") &
              (df_copy["FILE_ID"] != "Trinity_0051136")
               ))
# df_copy[df_copy["SITE_ID"] == "TRINITY"][Trinity_mask]
df_copy = df_copy[Trinity_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
print(df_copy[df_copy["SITE_ID"] == "UCLA_1"].to_string())
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject SITE_ID         FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  SEX HANDEDNESS_CATEGORY  HANDEDNESS_SCORES    FIQ    VIQ    PIQ FIQ_TEST_TYPE VIQ_TEST_TYPE PIQ_TEST_TYPE  ADI_R_SOCIAL_TOTAL_A  ADI_R_VERBAL_TOTAL_BV  ADI_RRB_TOTAL_C  ADI_R_ONSET_TOTAL_D  ADI_R_RSRCH_RELIABLE  ADOS_MODULE  ADOS_TOTAL  ADOS_COMM  ADOS_SOCIAL  ADOS_STEREO_BEHAV  ADOS_RSRCH_RELIABLE  ADOS_GOTHAM_SOCAFFECT  ADOS_GOTHAM_RRB  ADOS_GOTHAM_TOTAL  ADOS_GOTHAM_SEVERITY  SRS_VERSION  SRS_RAW_TOTAL  SRS_AWARENESS  SRS_COGNITION  SRS_COMMUNICATION  SRS_MOTIVATION  SRS_MANNERISMS  SCQ_TOTAL  AQ_TOTAL COMORBIDITY CURRENT_MED_STATUS                                                                         MEDICATION_NAME  OFF_STIMULANTS_AT_SCAN  VINELAND_RECEPTIVE_V_SCALED  VINELAND_EXPRESSIVE_V_SCALED  VINELAND_WRITTEN_V_SCALED  VINELAND_COMMUNICATION_STANDARD  VINELAND_PERSONAL_V_SCALED  VINELAND_DOMESTIC_V_SCALED  VINELAND_COMMUNITY_V_SCALED  VINELAND_DAILYLVNG_STANDARD 
# ...

# %%
UCLA_1_mask = ((df_copy["SITE_ID"] != "UCLA_1") | ((df_copy["FILE_ID"] != "UCLA_1_0051201") &
              (df_copy["FILE_ID"] != "UCLA_1_0051202") &
              (df_copy["FILE_ID"] != "UCLA_1_0051203") &
              (df_copy["FILE_ID"] != "UCLA_1_0051204") &
              (df_copy["FILE_ID"] != "UCLA_1_0051207") &
              (df_copy["FILE_ID"] != "UCLA_1_0051209") &
              (df_copy["FILE_ID"] != "UCLA_1_0051213") &
              (df_copy["FILE_ID"] != "UCLA_1_0051215") &
              (df_copy["FILE_ID"] != "UCLA_1_0051219") &
              (df_copy["FILE_ID"] != "UCLA_1_0051227") &
              (df_copy["FILE_ID"] != "UCLA_1_0051228") &
              (df_copy["FILE_ID"] != "UCLA_1_0051231") &
              (df_copy["FILE_ID"] != "UCLA_1_0051238") &
              (df_copy["FILE_ID"] != "UCLA_1_0051258") &
              (df_copy["FILE_ID"] != "UCLA_1_0051263") &
              (df_copy["FILE_ID"] != "UCLA_1_0051274") &
              (df_copy["FILE_ID"] != "UCLA_1_0051278")
               ))
# df_copy[df_copy["SITE_ID"] == "UCLA_1"][UCLA_1_mask]
df_copy = df_copy[UCLA_1_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "UCLA_2"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject SITE_ID         FILE_ID  \
# 960           960         961   51291  961    51291  UCLA_2  UCLA_2_0051291
# 961           961         962   51292  962    51292  UCLA_2  UCLA_2_0051292
# 962           962         963   51293  963    51293  UCLA_2  UCLA_2_0051293
# 963           963         964   51294  964    51294  UCLA_2  UCLA_2_0051294
# 964           964         965   51295  965    51295  UCLA_2  UCLA_2_0051295
# 965           965         966   51296  966    51296  UCLA_2  UCLA_2_0051296
# 966           966         967   51297  967    51297  UCLA_2  UCLA_2_0051297
# 967           967         968   51298  968    51298  UCLA_2  UCLA_2_0051298
# 968           968         969   51299  969    51299  UCLA_2  UCLA_2_0051299
# 969           969         970   51300  970    51300  UCLA_2  UCLA_2_0051300
# 970           970         971   51301  971    51301  UCLA_2  UCLA_2_0051301
# ...

# %%
UCLA_2_mask = ((df_copy["SITE_ID"] != "UCLA_2") | ((df_copy["FILE_ID"] != "UCLA_2_0051292") &
              (df_copy["FILE_ID"] != "UCLA_2_0051296") &
              (df_copy["FILE_ID"] != "UCLA_2_0051297") &
              (df_copy["FILE_ID"] != "UCLA_2_0051299") &
              (df_copy["FILE_ID"] != "UCLA_2_0051300") &
              (df_copy["FILE_ID"] != "UCLA_2_0051304")
               ))
# df_copy[df_copy["SITE_ID"] == "UCLA_2"][UCLA_2_mask]
df_copy = df_copy[UCLA_2_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "UM_1"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject SITE_ID       FILE_ID  \
# 195           195         196   50272  196    50272    UM_1  UM_1_0050272
# 196           196         197   50273  197    50273    UM_1  UM_1_0050273
# 197           197         198   50274  198    50274    UM_1  UM_1_0050274
# 198           198         199   50275  199    50275    UM_1  UM_1_0050275
# 199           199         200   50276  200    50276    UM_1  UM_1_0050276
# ..            ...         ...     ...  ...      ...     ...           ...
# 299           299         300   50376  300    50376    UM_1  UM_1_0050376
# 300           300         301   50377  301    50377    UM_1  UM_1_0050377
# 302           302         303   50379  303    50379    UM_1  UM_1_0050379
# 303           303         304   50380  304    50380    UM_1  UM_1_0050380
# 304           304         305   50381  305    50381    UM_1  UM_1_0050381
#
#      DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  qc_notes_rater_1 qc_anat_rater_2  \
# ...

# %%
UM_1_mask = ((df_copy["SITE_ID"] != "UM_1") | ((df_copy["FILE_ID"] != "UM_1_0050279") &
              (df_copy["FILE_ID"] != "UM_1_0050281") &
              (df_copy["FILE_ID"] != "UM_1_0050286") &
              (df_copy["FILE_ID"] != "UM_1_0050288") &
              (df_copy["FILE_ID"] != "UM_1_0050296") &
              (df_copy["FILE_ID"] != "UM_1_0050299") &
              (df_copy["FILE_ID"] != "UM_1_0050303") &
              (df_copy["FILE_ID"] != "UM_1_0050304") &
              (df_copy["FILE_ID"] != "UM_1_0050305") &
              (df_copy["FILE_ID"] != "UM_1_0050306") &
              (df_copy["FILE_ID"] != "UM_1_0050308") &
              (df_copy["FILE_ID"] != "UM_1_0050311") &
              (df_copy["FILE_ID"] != "UM_1_0050312") &
              (df_copy["FILE_ID"] != "UM_1_0050313") &
              (df_copy["FILE_ID"] != "UM_1_0050316") &
              (df_copy["FILE_ID"] != "UM_1_0050317") &
              (df_copy["FILE_ID"] != "UM_1_0050322") &
              (df_copy["FILE_ID"] != "UM_1_0050333") &
              (df_copy["FILE_ID"] != "UM_1_0050354") &
              (df_copy["FILE_ID"] != "UM_1_0050359") &
              (df_copy["FILE_ID"] != "UM_1_0050371") &
              (df_copy["FILE_ID"] != "UM_1_0050376") &
              (df_copy["FILE_ID"] != "UM_1_0050380") &
              (df_copy["FILE_ID"] != "UM_1_0050381") 
               ))
# df_copy[df_copy["SITE_ID"] == "UM_1"][UM_1_mask]
df_copy = df_copy[UM_1_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "UM_2"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject SITE_ID       FILE_ID  \
# 305           305         306   50382  306    50382    UM_2  UM_2_0050382
# 306           306         307   50383  307    50383    UM_2  UM_2_0050383
# 307           307         308   50385  308    50385    UM_2  UM_2_0050385
# 308           308         309   50386  309    50386    UM_2  UM_2_0050386
# 309           309         310   50387  310    50387    UM_2  UM_2_0050387
# 310           310         311   50388  311    50388    UM_2  UM_2_0050388
# 311           311         312   50390  312    50390    UM_2  UM_2_0050390
# 312           312         313   50391  313    50391    UM_2  UM_2_0050391
# 313           313         314   50397  314    50397    UM_2  UM_2_0050397
# 314           314         315   50399  315    50399    UM_2  UM_2_0050399
# 315           315         316   50402  316    50402    UM_2  UM_2_0050402
# 316           316         317   50403  317    50403    UM_2  UM_2_0050403
# ...

# %%
UM_2_mask = ((df_copy["SITE_ID"] != "UM_2") | ((df_copy["FILE_ID"] != "UM_2_0050383") &
              (df_copy["FILE_ID"] != "UM_2_0050402") &
              (df_copy["FILE_ID"] != "UM_2_0050422")
               ))
# df_copy[df_copy["SITE_ID"] == "UM_2"][UM_2_mask]
df_copy = df_copy[UM_2_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
print(df_copy[df_copy["SITE_ID"] == "USM"].to_string())
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject SITE_ID      FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  SEX HANDEDNESS_CATEGORY  HANDEDNESS_SCORES    FIQ    VIQ    PIQ FIQ_TEST_TYPE VIQ_TEST_TYPE PIQ_TEST_TYPE  ADI_R_SOCIAL_TOTAL_A  ADI_R_VERBAL_TOTAL_BV  ADI_RRB_TOTAL_C  ADI_R_ONSET_TOTAL_D  ADI_R_RSRCH_RELIABLE  ADOS_MODULE  ADOS_TOTAL  ADOS_COMM  ADOS_SOCIAL  ADOS_STEREO_BEHAV  ADOS_RSRCH_RELIABLE  ADOS_GOTHAM_SOCAFFECT  ADOS_GOTHAM_RRB  ADOS_GOTHAM_TOTAL  ADOS_GOTHAM_SEVERITY  SRS_VERSION  SRS_RAW_TOTAL  SRS_AWARENESS  SRS_COGNITION  SRS_COMMUNICATION  SRS_MOTIVATION  SRS_MANNERISMS  SCQ_TOTAL  AQ_TOTAL COMORBIDITY CURRENT_MED_STATUS MEDICATION_NAME  OFF_STIMULANTS_AT_SCAN  VINELAND_RECEPTIVE_V_SCALED  VINELAND_EXPRESSIVE_V_SCALED  VINELAND_WRITTEN_V_SCALED  VINELAND_COMMUNICATION_STANDARD  VINELAND_PERSONAL_V_SCALED  VINELAND_DOMESTIC_V_SCALED  VINELAND_COMMUNITY_V_SCALED  VINELAND_DAILYLVNG_STANDARD  VINELAND_INTERPERSONAL_V_SCALED  VINELAND_PLAY_V_SCALED  VINELAND_COPING_V
# ...

# %%
USM_mask = ((df_copy["SITE_ID"] != "USM") | ((df_copy["FILE_ID"] != "USM_0050453") &
              (df_copy["FILE_ID"] != "USM_0050470") &
              (df_copy["FILE_ID"] != "USM_0050481") &
              (df_copy["FILE_ID"] != "USM_0050489") &
              (df_copy["FILE_ID"] != "USM_0050501") &
              (df_copy["FILE_ID"] != "USM_0050509") &
              (df_copy["FILE_ID"] != "USM_0050510") &
              (df_copy["FILE_ID"] != "USM_0050511") &
              (df_copy["FILE_ID"] != "USM_0050523") &
              (df_copy["FILE_ID"] != "USM_0050531")
               ))
# df_copy[df_copy["SITE_ID"] == "USM"][USM_mask]
df_copy = df_copy[USM_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
df_copy[df_copy["SITE_ID"] == "YALE"]
# Out:
#      Unnamed: 0.1  Unnamed: 0  SUB_ID    X  subject SITE_ID       FILE_ID  \
# 441           441         442   50551  442    50551    YALE  Yale_0050551
# 442           442         443   50552  443    50552    YALE  Yale_0050552
# 443           443         444   50553  444    50553    YALE  Yale_0050553
# 444           444         445   50554  445    50554    YALE  Yale_0050554
# 445           445         446   50555  446    50555    YALE  Yale_0050555
# 446           446         447   50556  447    50556    YALE  Yale_0050556
# 447           447         448   50557  448    50557    YALE  Yale_0050557
# 448           448         449   50558  449    50558    YALE  Yale_0050558
# 449           449         450   50559  450    50559    YALE  Yale_0050559
# 450           450         451   50560  451    50560    YALE  Yale_0050560
# 451           451         452   50561  452    50561    YALE  Yale_0050561
# 452           452         453   50562  453    50562    YALE  Yale_0050562
# ...

# %%
Yale_mask = ((df_copy["SITE_ID"] != "YALE") | ((df_copy["FILE_ID"] != "Yale_0050565") &
              (df_copy["FILE_ID"] != "Yale_0050578") &
              (df_copy["FILE_ID"] != "Yale_0050602") &
              (df_copy["FILE_ID"] != "Yale_0050608") &
              (df_copy["FILE_ID"] != "Yale_0050610") &
              (df_copy["FILE_ID"] != "Yale_0050615") &
              (df_copy["FILE_ID"] != "Yale_0050615") &
              (df_copy["FILE_ID"] != "Yale_0050618") &
              (df_copy["FILE_ID"] != "Yale_0050622")
               ))
# df_copy[df_copy["SITE_ID"] == "YALE"][Yale_mask]
df_copy = df_copy[Yale_mask]
df_copy
# Out:
#       Unnamed: 0.1  Unnamed: 0  SUB_ID     X  subject  SITE_ID  \
# 2                2           3   50004     3    50004     PITT
# 3                3           4   50005     4    50005     PITT
# 4                4           5   50006     5    50006     PITT
# 5                5           6   50007     6    50007     PITT
# 6                6           7   50008     7    50008     PITT
# ...            ...         ...     ...   ...      ...      ...
# 1107          1107        1108   51583  1108    51583      SBL
# 1108          1108        1109   51584  1109    51584      SBL
# 1109          1109        1110   51585  1110    51585      SBL
# 1110          1110        1111   51606  1111    51606  MAX_MUN
# 1111          1111        1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN  ...  \
# 2         Pitt_0050004         1          1        19.09  ...
# 3         Pitt_0050005         1          1        13.73  ...
# ...

# %%
df_copy.to_csv("../Data/removed_cols.csv", index=False)
